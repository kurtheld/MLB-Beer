# %%
import pandas as pd
# Dependencies
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
from splinter import Browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome(r'/usr/local/bin/chromedriver')
driver.get("https://www.beeradvocate.com/search/")

# %%
from selenium import webdriver
import time

# %%
df=pd.read_csv('beer_team.csv')

# %%
df
# Out:
#      Unnamed: 0                 Teams  \
# 0             0  Arizona Diamondbacks
# 1             1  Arizona Diamondbacks
# 2             2  Arizona Diamondbacks
# 3             3  Arizona Diamondbacks
# 4             4  Arizona Diamondbacks
# 5             5        Atlanta Braves
# 6             6        Atlanta Braves
# 7             7        Atlanta Braves
# 8             8        Atlanta Braves
# 9             9        Atlanta Braves
# 10           10        Atlanta Braves
# 11           11        Atlanta Braves
# 12           12        Atlanta Braves
# 13           13        Atlanta Braves
# 14           14        Atlanta Braves
# 15           15        Boston Red Sox
# 16           16        Boston Red Sox
# 17           17        Boston Red Sox
# 18           18        Boston Red Sox
# 19           19          Chicago Cubs
# 20           20          Chicago Cubs
# 21           21          Chicago Cubs
# 22           22          Chicago Cubs
# 23           23     Chicago White Sox
# 24           24     Chicago White Sox
# 25           25     Chicago White Sox
# 26           26     Chicago White Sox
# 27           27     Chicago White Sox
# 28           28      Colorado Rockies
# 29           29      Colorado Rockies
# ..          ...                   ...
# 228         228         Texas Rangers
# 229         229         Texas Rangers
# 230         230         Texas Rangers
# 231         231         Texas Rangers
# 232         232         Texas Rangers
# 233         233     Milwaukee Brewers
# 234         234     Milwaukee Brewers
# 235         235     Milwaukee Brewers
# 236         236     Milwaukee Brewers
# 237         237     Milwaukee Brewers
# 238         238    Pittsburgh Pirates
# 239         239    Pittsburgh Pirates
# 240         240    Pittsburgh Pirates
# 241         241    Pittsburgh Pirates
# 242         242    Pittsburgh Pirates
# 243         243     Cleveland Indians
# 244         244     Cleveland Indians
# 245         245     Cleveland Indians
# 246         246     Cleveland Indians
# 247         247     Cleveland Indians
# 248         248     Toronto Blue Jays
# 249         249     Toronto Blue Jays
# 250         250     Toronto Blue Jays
# 251         251     Toronto Blue Jays
# 252         252     Toronto Blue Jays
# 253         253        Tampa Bay Rays
# 254         254        Tampa Bay Rays
# 255         255        Tampa Bay Rays
# 256         256        Tampa Bay Rays
# 257         257        Tampa Bay Rays
#
#                                             Beers
# 0                       Samuel Adams Boston Lager
# 1              Goose Island Beer Co. Honker's Ale
# 2           Goose Island Beer Co. 312 Urban Wheat
# 3                         Blue Moon Belgian White
# 4               Phoenix Ale Brewery Camelback IPA
# 5                                  Sweetwater IPA
# 6                        Sweetwater LowRYEder IPA
# 7                   Sweetwater 420 Extra Pale Ale
# 8                         Sweetwater Georgia Brow
# 9                          Terrapin Hopsecutioner
# 10                                      Yuengling
# 11                                Yuengling Light
# 12                   Goose Island Brewing Co. IPA
# 13                   Goose Island Brewing Co. 312
# 14                       Blue Point Toasted Lager
# 15                   Smuttynose IPA "Finest Kind"
# 16             Goose Island Beer Co. Honker's Ale
# 17                       Harpoon Octoberfest Beer
# 18            Cisco Brewers Whale's Tale Pale Ale
# 19                    Goose Island Beer Co. Sofie
# 20                  Goose Island Beer Co. Matilda
# 21               Goose Island Beer Co. Green Line
# 22          Goose Island Beer Co. 312 Urban Wheat
# 23   Half Acre Beer Company Daisy Cutter Pale Ale
# 24           Revolution Brewing Company Anti-Hero
# 25              Lagunitas Brewing Company DayTime
# 26                         Sierra Nevada Pale Ale
# 27                        Rogue Ales Dead Guy Ale
# 28             Great Divide Brewing Co. Titan IPA
# 29                    Oskar Blues Dale's Pale Ale
# ..                                            ...
# 228                        Sierra Nevada Pale Ale
# 229                   Oskar Blues Dale's Pale Ale
# 230                          Founders All Day IPA
# 231                         Odell 90 Shilling Ale
# 232                               Franconia Lager
# 233               Sierra Nevada Torpedo Extra IPA
# 234                        Sierra Nevada Pale Ale
# 235                             Bell's Oberon Ale
# 236               Milwaukee Brewing Company O-Gii
# 237                    New Belgium Brewing Ranger
# 238                        Bell's Two Hearted Ale
# 239        Lagunitas A Little Sumpin' Sumpin' Ale
# 240                 Dogfish Head Indian Brown Ale
# 241                    Dogfish Head 60 Minute IPA
# 242                         Victory Hop Devil Ale
# 243                    Fat Head's Head Hunter IPA
# 244                   The Brew Kettle White Rajah
# 245                        Bell's Two Hearted Ale
# 246                    Dogfish Head 60 Minute IPA
# 247                   Great Lakes Dortmunder Gold
# 248              Alexander Keith's Galaxy Hop Ale
# 249        Alexander Keith's Hallertauer Hope Ale
# 250             Alexander Keith's Cascade Hop Ale
# 251                                 Stella Artois
# 252                 Labatt Canadian Ale/Labatt 50
# 253                     Samuel Adams Boston Lager
# 254                New Belgium Fat Tire Amber Ale
# 255                       Blue Moon Belgian White
# 256                                      Batch 19
# 257                  Leinenkugel's Summer Shandy
#
# [258 rows x 3 columns]

# %%
df['Beers']= df.apply(lambda row: row['Beers'].split('</b>',1)[-1],axis=1)

# %%
df
# Out:
#      Unnamed: 0                 Teams  \
# 0             0  Arizona Diamondbacks
# 1             1  Arizona Diamondbacks
# 2             2  Arizona Diamondbacks
# 3             3  Arizona Diamondbacks
# 4             4  Arizona Diamondbacks
# 5             5        Atlanta Braves
# 6             6        Atlanta Braves
# 7             7        Atlanta Braves
# 8             8        Atlanta Braves
# 9             9        Atlanta Braves
# 10           10        Atlanta Braves
# 11           11        Atlanta Braves
# 12           12        Atlanta Braves
# 13           13        Atlanta Braves
# 14           14        Atlanta Braves
# 15           15        Boston Red Sox
# 16           16        Boston Red Sox
# 17           17        Boston Red Sox
# 18           18        Boston Red Sox
# 19           19          Chicago Cubs
# 20           20          Chicago Cubs
# 21           21          Chicago Cubs
# 22           22          Chicago Cubs
# 23           23     Chicago White Sox
# 24           24     Chicago White Sox
# 25           25     Chicago White Sox
# 26           26     Chicago White Sox
# 27           27     Chicago White Sox
# 28           28      Colorado Rockies
# 29           29      Colorado Rockies
# ..          ...                   ...
# 228         228         Texas Rangers
# 229         229         Texas Rangers
# 230         230         Texas Rangers
# 231         231         Texas Rangers
# 232         232         Texas Rangers
# 233         233     Milwaukee Brewers
# 234         234     Milwaukee Brewers
# 235         235     Milwaukee Brewers
# 236         236     Milwaukee Brewers
# 237         237     Milwaukee Brewers
# 238         238    Pittsburgh Pirates
# 239         239    Pittsburgh Pirates
# 240         240    Pittsburgh Pirates
# 241         241    Pittsburgh Pirates
# 242         242    Pittsburgh Pirates
# 243         243     Cleveland Indians
# 244         244     Cleveland Indians
# 245         245     Cleveland Indians
# 246         246     Cleveland Indians
# 247         247     Cleveland Indians
# 248         248     Toronto Blue Jays
# 249         249     Toronto Blue Jays
# 250         250     Toronto Blue Jays
# 251         251     Toronto Blue Jays
# 252         252     Toronto Blue Jays
# 253         253        Tampa Bay Rays
# 254         254        Tampa Bay Rays
# 255         255        Tampa Bay Rays
# 256         256        Tampa Bay Rays
# 257         257        Tampa Bay Rays
#
#                                             Beers
# 0                       Samuel Adams Boston Lager
# 1              Goose Island Beer Co. Honker's Ale
# 2           Goose Island Beer Co. 312 Urban Wheat
# 3                         Blue Moon Belgian White
# 4               Phoenix Ale Brewery Camelback IPA
# 5                                  Sweetwater IPA
# 6                        Sweetwater LowRYEder IPA
# 7                   Sweetwater 420 Extra Pale Ale
# 8                         Sweetwater Georgia Brow
# 9                          Terrapin Hopsecutioner
# 10                                      Yuengling
# 11                                Yuengling Light
# 12                   Goose Island Brewing Co. IPA
# 13                   Goose Island Brewing Co. 312
# 14                       Blue Point Toasted Lager
# 15                   Smuttynose IPA "Finest Kind"
# 16             Goose Island Beer Co. Honker's Ale
# 17                       Harpoon Octoberfest Beer
# 18            Cisco Brewers Whale's Tale Pale Ale
# 19                    Goose Island Beer Co. Sofie
# 20                  Goose Island Beer Co. Matilda
# 21               Goose Island Beer Co. Green Line
# 22          Goose Island Beer Co. 312 Urban Wheat
# 23   Half Acre Beer Company Daisy Cutter Pale Ale
# 24           Revolution Brewing Company Anti-Hero
# 25              Lagunitas Brewing Company DayTime
# 26                         Sierra Nevada Pale Ale
# 27                        Rogue Ales Dead Guy Ale
# 28             Great Divide Brewing Co. Titan IPA
# 29                    Oskar Blues Dale's Pale Ale
# ..                                            ...
# 228                        Sierra Nevada Pale Ale
# 229                   Oskar Blues Dale's Pale Ale
# 230                          Founders All Day IPA
# 231                         Odell 90 Shilling Ale
# 232                               Franconia Lager
# 233               Sierra Nevada Torpedo Extra IPA
# 234                        Sierra Nevada Pale Ale
# 235                             Bell's Oberon Ale
# 236               Milwaukee Brewing Company O-Gii
# 237                    New Belgium Brewing Ranger
# 238                        Bell's Two Hearted Ale
# 239        Lagunitas A Little Sumpin' Sumpin' Ale
# 240                 Dogfish Head Indian Brown Ale
# 241                    Dogfish Head 60 Minute IPA
# 242                         Victory Hop Devil Ale
# 243                    Fat Head's Head Hunter IPA
# 244                   The Brew Kettle White Rajah
# 245                        Bell's Two Hearted Ale
# 246                    Dogfish Head 60 Minute IPA
# 247                   Great Lakes Dortmunder Gold
# 248              Alexander Keith's Galaxy Hop Ale
# 249        Alexander Keith's Hallertauer Hope Ale
# 250             Alexander Keith's Cascade Hop Ale
# 251                                 Stella Artois
# 252                 Labatt Canadian Ale/Labatt 50
# 253                     Samuel Adams Boston Lager
# 254                New Belgium Fat Tire Amber Ale
# 255                       Blue Moon Belgian White
# 256                                      Batch 19
# 257                  Leinenkugel's Summer Shandy
#
# [258 rows x 3 columns]

# %%
df.to_csv('beer_new.csv')

# %%
def get_brewery(beer):
    driver.get("https://www.beeradvocate.com/search/")
    inputElement = driver.find_element_by_xpath("//form[@name='sF']/input[1]")
    inputElement.clear()
    #inputElement.click()
    inputElement.send_keys(beer)
    #time.sleep(6)
    search= driver.find_element_by_xpath("//form[@name='sF']/input[2]")
    search.click()
    url=driver.current_url
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    if 'beer/profile' in url:
        brewery=soup.find('title').get_text().split('|')[1]
    else:
        for i in soup.find_all('a'):
        if ('beer/profile' in str(i)) and ('span' not in str(i)):
            #print(i)
            brewery=i.get_text()
            break
    #breweries = soup.find_all('title')
    #brewery=breweries[0].get_text().split('|')[1]
    return brewery

# %%
url='https://www.beeradvocate.com/beer/profile/192/607/'

# %%
if 'beer/profile' in url:
    print(True)
# Out:
# True

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
brewery=soup.find('title').get_text()#.split('|')[1]
brewery
# Out:
# 'Fat Tire Amber Ale | New Belgium Brewing | BeerAdvocate'

# %%
brewery=breweries[0].get_text().split('|')[1]
brewery
# Out:
# ' New Belgium Brewing '

# %%
def get_b1(soup):
    breweries = soup.find_all('title')
    brewery=breweries[0].get_text().split('|')[1]

# %%
def get_b2(url):
    for i in soup.find_all('a'):
        if ('beer/profile' in str(i)) and ('span' not in str(i)):
            #print(i)
            return(i.get_text())
            break

# %%
beer_brewery("Batch 19")
# Out:
# ' BeerAdvocate'

# %%
driver.get("https://www.beeradvocate.com/search/")
    inputElement = driver.find_element_by_xpath("//form[@name='sF']/input[1]")
    inputElement.clear()
    #inputElement.click()
    inputElement.send_keys(beer)
    #time.sleep(6)
    search= driver.find_element_by_xpath("//form[@name='sF']/input[2]")
    search.click()
    url=driver.current_url
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

# %%
Brewery = []
Test=["Leinenkugel's Summer Shandy","Batch 19","New Belgium Fat Tire Amber Ale","The Brew Kettle White Rajah","Fat Head's Head Hunter IPA"]
#for _, row in df.iterrows():
    #beer = row.Test
for beer in Test:
    url=get_url(beer)
    try:
        brewery=get_b1(url)
    except:
        brewery=get_b2(url)
    Brewery.append(brewery)

# %%
Brewery
# Out:
# [None, None, None, None, None]

# %%
url='https://www.beeradvocate.com/search/?q=Leinenkugel%27s+Summer+Shandy&qt=beer'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="Public NoJs uix_javascriptNeedsInit LoggedOut Sidebar Responsive pageIsLtr not_hasTabLinks hasSearch is-sidebarOpen hasRightSidebar is-setWidth navStyle_0 pageStyle_0 hasFlexbox" dir="LTR" id="XenForo" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <base href="https://www.beeradvocate.com/community/"/>\n  <script>\n   var _b = document.getElementsByTagName(\'base\')[0], _bH = "https://www.beeradvocate.com/community/";\n\t\t\tif (_b && _b.href != _bH) _b.href = _bH;\n  </script>\n  <title>\n   Search | BeerAdvocate\n  </title>\n  <noscript>\n   <style>\n    .JsOnly, .jsOnly { display: none !important; }\n   </style>\n  </noscript>\n  <link href="css.php?css=xenforo,form,public&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <link href="css.php?css=login_bar,moderator_bar,notices,uix_extendedFooter&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <link href="css.php?css=uix,uix_style&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <style>\n   /*** UIX -- PER USER STYLES ***/\n  </style>\n  <link href="css.php?css=EXTRA&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <style>\n   /* Node Styling */\n  </style>\n  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1066712-1">\n  </script>\n  <script>\n   window.dataLayer = window.dataLayer || [];\n\t\tfunction gtag(){dataLayer.push(arguments);}\n\t\tgtag(\'js\', new Date());\n\t\tgtag(\'config\', \'UA-1066712-1\', {\n  \t\t\t\'cookie_domain\': \'www.beeradvocate.com\',\n\t\t\t// <!-- slot: ga_config_start -->\n\t\t\t\n\t\t\t\n\t\t});\n  </script>\n  <link href="styles/uix/uix/css/font-awesome.min.css" rel="stylesheet"/>\n  <link href="//fonts.googleapis.com/css?family=Open+Sans:300,400,700,600" rel="stylesheet" type="text/css"/>\n  <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.7.2/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" rel="stylesheet"/>\n  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">\n  </script>\n  <script>\n   if (!window.jQuery) { document.write(\'<scr\'+\'ipt type="text/javascript" src="js/jquery/jquery-1.11.0.min.js"><\\/scr\'+\'ipt>\'); }\n  </script>\n  <script src="js/xenforo/xenforo.js?_v=3fb40d2d">\n  </script>\n  <!--[if lt IE 9]>\n\t\n\t\t \n        \t<script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.2/html5shiv.min.js"></script>\n\t        \n\t        <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.js"></script>\n\t        \n\t        <script src="//cdnjs.cloudflare.com/ajax/libs/selectivizr/1.0.2/selectivizr-min.js"></script>\n\t\n\n<![endif]-->\n  <script>\n   uix = {\n\t\telm: {},\n\t\tfn:{},\n\t\tinit: function(){\n\t\t\tif (uix.betaMode) {\n\t\t\t\tconsole.group(\'uix.%cinit()\', \'color:#3498DB\');\n\t\t\t}\n\t\t\tfor(var x=0;x<uix.events.init.length;x++){\n\t\t\t\tuix.events.init[x]()\n\t\t  \t}\n\t\t  \tconsole.groupEnd(\'uix.%cinit()\',\'color:#3498DB\')\n\t\t},\n\t  \tevents: {init:[]},\n\t  \ton: function(event, fn){\n\t  \t\tif(event==\'init\'){\n\t  \t\t\tuix.events.init.push(fn)\n\t  \t\t}\n\t  \t},\n\n\t\tbetaMode\t\t\t\t: parseInt(\'0\'),\n\t\tjsPathUsed\t\t\t\t: \'uix_style\',\n\t\tjsGlobal\t\t\t\t: parseInt(\'0\'),\n\n\n\t  \tversion\t\t\t\t\t: \'1.5.22.0\',\n\t  \tjsHeadVersion\t\t\t\t: \'1.5.16.0a\',\n\t  \taddonVersion\t\t\t\t: \'1010270\',\n\t  \tjsCacheBust\t\t\t\t: \'1\',\n\t  \tcontentTemplate\t\t\t\t: \'bridge_page\',\n\n\t\tjavascriptInitHide\t\t\t: parseInt(\'1\'),\n\t\tglobalPadding \t\t\t\t: parseInt(\'16px\'),\n\t\tsidebarWidth\t\t\t\t: parseInt(\'300px\'),\n\t\tmainContainerMargin  \t        \t: \'316px\',\n\t\tmaxResponsiveWideWidth   \t\t: parseInt(\'850px\'),\n\t\tmaxResponsiveMediu ...

# %%
soup.find_all('a')
# Out:
# [<a class="js-panelMask uix_panelMask" href="#"></a>,
#  <a class="navLink" href="/">Home</a>,
#  <a class="SplitCtrl" href="/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/about/">About Us</a>,
#  <a href="/advertise/">Advertise</a>,
#  <a href="/contact/">Contact Us</a>,
#  <a href="/community/forums/help-resources.32/">Help</a>,
#  <a href="/members/">Our Community</a>,
#  <a href="/events/">Our Events</a>,
#  <a href="/magazine/">Our Magazine</a>,
#  <a href="/respect-beer/">Respect Beer®</a>,
#  <a class="navLink" href="https://www.beeradvocate.com/community/">Forums</a>,
#  <a class="SplitCtrl" href="https://www.beeradvocate.com/community/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="search/?type=post">Search Forums</a>,
#  <a href="find-new/posts" rel="nofollow">Recent Posts</a>,
#  <a class="navLink" href="/beer/">Beers</a>,
#  <a class="SplitCtrl" href="/beer/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/user/beers/">Your Beers</a>,
#  <a href="/forms/add-beer/">Add a Beer</a>,
#  <a href="/beer/">Recent Reviews</a>,
#  <a href="/beer/styles/">Beer Styles</a>,
#  <a href="/lists/top/">Top Rated Beers</a>,
#  <a href="/lists/new/">Top Rated Beers: New</a>,
#  <a href="/lists/fame/">Beers of Fame</a>,
#  <a href="/lists/popular/">Most Popular Beers</a>,
#  <a href="/trading/">Trading</a>,
#  <a class="navLink" href="/trading/">Trading</a>,
#  <a class="SplitCtrl" href="/trading/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/user/trades/">Your Trades</a>,
#  <a href="/community/categories/iso-ft.83/">Post a Trade</a>,
#  <a href="/community/#trading.81">Forums</a>,
#  <a href="/community/threads/trading-rules-tips.229/">Rules &amp; Tips</a>,
#  <a href="/community/threads/trading-feedback-system-explained.185895/">Feedback Help</a>,
#  <a class="navLink" href="/place/">Places</a>,
#  <a class="SplitCtrl" href="/place/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/user/places/">Your Places</a>,
#  <a href="/toolbox/add_place/">Add a Place</a>,
#  <a href="/place/reviews/">Recent Reviews</a>,
#  <a href="/place/directory/">Directory</a>,
#  <a href="/place/nearby/">Nearby</a>,
#  <a class="navLink" href="/events/calendar/">Events</a>,
#  <a class="SplitCtrl" href="/events/calendar/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/user/events/">Your Events / Invites</a>,
#  <a href="/forms/events/">Add an Event</a>,
#  <a href="/events/calendar/">Calendar</a>,
#  <a href="/events/">About Our Events</a>,
#  <a href="/ipa/">IPA Fest: Brooklyn</a>,
#  <a class="navLink" href="/articles/">Articles</a>,
#  <a class="SplitCtrl" href="/articles/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/articles/category/food-drink/">Food &amp; Drink</a>,
#  <a href="/articles/category/history-culture/">History &amp; Culture</a>,
#  <a href="/articles/category/news/">News</a>,
#  <a href="/articles/category/opinion/">Opinion</a>,
#  <a href="/articles/category/people-places/">People &amp; Places</a>,
#  <a href="/articles/category/science-technology/">Science &amp; Technology</a>,
#  <a href="/articles/category/travel/">Travel</a>,
#  <a href="/beer/101/">Beer 101</a>,
#  <a href="/articles/archive/">Magazine Issue Archive</a>,
#  <a class="navLink" href="/society/">Society</a>,
#  <a class="SplitCtrl" href="/society/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/society/">Join</a>,
#  <a href="/society/members/">Members</a>,
#  <a href="/community/threads/respect-beer-society-membership-drive-gathering.610904/">Gatherings</a>,
#  <a class="navLink" href="/sponsorship/">Sponsorship</a>,
#  <a class="SplitCtrl" href="/sponsorship/"><i class="uix_icon js-offcanvasIcon uix_icon-expandDropdown"></i></a>,
#  <a href="/sponsorship/">Become a Sponsor</a>,
#  <a href="/sponsorship/thanks/">Our Sponsors</a>,
#  <a class="js-panelMask uix_panelMask" href="#"></a>,
#  <a class="OverlayTrigger OverlayCloser" href="lost-password/" tabindex="26">Forgot your password?</a>,
#  <a class="js-panelMask uix_panelMask" href="#"></a>,
#  <a href="https://www.beeradvocate.com">
#  <span></span>
#  <img alt="BeerAdvocate" src="https://cdn.beeradvocate.com/im/beeradvocate-nav-logo.png"/>
#  <div class="uix_slogan">Your Go-To Resource for Beer. | Respect Beer®</div>
#  </a>,
#  <a href="https://www.beeradvocate.com">
#  <img src="https://cdn.beeradvocate.com/im/beeradvocate-nav-brandmark.png"/>
#  </a>,
#  <a class="navLink js-leftPanelTrigger" href="#">
#  <i class="uix_icon uix_icon-menu"></i><span class="trigger__phrase">Menu</span>
#  </a>,
#  <a class="navLink NoPopupGadget" href="/" rel="Menu">Home</a>,
#  <a class="SplitCtrl" href="/" rel="Menu"></a>,
#  <a href="/about/">About Us</a>,
#  <a href="/advertise/">Advertise</a>,
#  <a href="/contact/">Contact Us</a>,
#  <a href="/community/forums/help-resources.32/">Help</a>,
#  <a href="/members/">Our Community</a>,
#  <a href="/events/">Our Events</a>,
#  <a href="/magazine/">Our Magazine</a>,
#  <a href="/respect-beer/">Respect Beer®</a>,
#  <a class="navLink NoPopupGadget" href="https://www.beeradvocate.com/community/" rel="Menu">Forums</a>,
#  <a class="SplitCtrl" href="https://www.beeradvocate.com/community/" rel="Menu"></a>,
#  <a href="search/?type=post">Search Forums</a>,
#  <a href="find-new/posts" rel="nofollow">Recent Posts</a>,
#  <a href="/members/">Members</a>,
#  <a class="navLink NoPopupGadget" href="/beer/" rel="Menu">Beers</a>,
#  <a class="SplitCtrl" href="/beer/" rel="Menu"></a>,
#  <a href="/user/beers/">Your Beers</a>,
#  <a href="/forms/add-beer/">Add a Beer</a>,
#  <a href="/beer/">Recent Reviews</a>,
#  <a href="/beer/styles/">Beer Styles</a>,
#  <a href="/lists/top/">Top Rated Beers</a>,
#  <a href="/lists/new/">Top Rated Beers: New</a>,
#  <a href="/lists/fame/">Beers of Fame</a>,
#  <a href="/lists/popular/">Most Popular Beers</a>,
#  <a href="/trading/">Trading</a>,
#  <a class="navLink NoPopupGadget" href="/trading/" rel="Menu">Trading</a>,
#  <a class="SplitCtrl" href="/trading/" rel="Menu"></a>,
#  <a href="/user/trades/">Your Trades</a>,
#  <a href="/community/categories/iso-ft.83/">Post a Trade</a>,
#  <a href="/community/#trading.81">Forums</a>,
#  <a href="/community/threads/trading-rules-tips.229/">Rules &amp; Tips</a>,
#  <a href="/community/threads/trading-feedback-system-explained.185895/">Feedback Help</a>,
#  <a class="navLink NoPopupGadget" href="/place/" rel="Menu">Places</a>,
#  <a class="SplitCtrl" href="/place/" rel="Menu"></a>,
#  <a href="/user/places/">Your Places</a>,
#  <a href="/toolbox/add_place/">Add a Place</a>,
#  <a href="/place/reviews/">Recent Reviews</a>,
#  <a href="/place/directory/">Directory</a>,
#  <a href="/place/nearby/">Nearby</a>,
#  <a class="navLink NoPopupGadget" href="/events/calendar/" rel="Menu">Events</a>,
#  <a class="SplitCtrl" href="/events/calendar/" rel="Menu"></a>,
#  <a href="/user/events/">Your Events / Invites</a>,
#  <a href="/forms/events/">Add an Event</a>,
#  <a href="/events/calendar/">Calendar</a>,
#  <a href="/events/">About Our Events</a>,
#  <a href="/ipa/">IPA Fest: Brooklyn</a>,
#  <a class="navLink NoPopupGadget" href="/articles/" rel="Menu">Articles</a>,
#  <a class="SplitCtrl" href="/articles/" rel="Menu"></a>,
#  <a href="/articles/category/food-drink/">Food &amp; Drink</a>,
#  <a href="/articles/category/history-culture/">History &amp; Culture</a>,
#  <a href="/articles/category/news/">News</a>,
#  <a href="/articles/category/opinion/">Opinion</a>,
#  <a href="/articles/category/people-places/">People &amp; Places</a>,
#  <a href="/articles/category/science-technology/">Science &amp; Technology</a>,
#  <a href="/articles/category/travel/">Travel</a>,
#  <a href="/beer/101/">Beer 101</a>,
#  <a href="/articles/archive/">Magazine Issue Archive</a>,
#  <a class="navLink NoPopupGadget" href="/society/" rel="Menu">Society</a>,
#  <a class="SplitCtrl" href="/society/" rel="Menu"></a>,
#  <a href="/society/">Join</a>,
#  <a href="/society/members/">Members</a>,
#  <a href="/community/threads/respect-beer-society-membership-drive-gathering.610904/">Gatherings</a>,
#  <a class="navLink NoPopupGadget" href="/sponsorship/" rel="Menu">Sponsorship</a>,
#  <a class="SplitCtrl" href="/sponsorship/" rel="Menu"></a>,
#  <a href="/sponsorship/">Become a Sponsor</a>,
#  <a href="/sponsorship/thanks/">Our Sponsors</a>,
#  <a class="navLink NoPopupGadget uix_dropdownDesktopMenu" rel="Menu"><i class="uix_icon uix_icon-navOverflow"></i><span class="uix_hide menuIcon">Menu</span></a>,
#  <a class="navLink uix_dropdownDesktopMenu OverlayTrigger" data-cacheoverlay="false" href="login/">
#  <i class="uix_icon uix_icon-signIn"></i>
#  <strong class="loginText">Log in</strong>
#  </a>,
#  <a class="navLink" href="register/">
#  <i class="uix_icon uix_icon-register"></i>
#  <strong>Sign up</strong>
#  </a>,
#  <a class="OverlayTrigger jumpMenuTrigger" data-cacheoverlay="true" href="misc/quick-navigation-menu" title="Open quick navigation"><i class="uix_icon uix_icon-sitemap"></i></a>,
#  <a class="crumb" href="/" itemprop="url" rel="up"><span itemprop="title"><i class="uix_icon uix_icon-home" title="Home"></i><span class="uix_breadcrumb__home__title">Home</span></span></a>,
#  <a class="crumb" href="/search/" itemprop="url" rel="up"><span itemprop="title">Search</span></a>,
#  <a class="DismissCtrl Tooltip" data-offsetx="7" data-tipclass="flipped" href="account/dismiss-notice?notice_id=3" title="Dismiss Notice">Dismiss Notice</a>,
#  <a href="/ipa/">Don't miss <b>IPA Fest: Brooklyn</b> on September 14!<br/><br/><b>Tickets are on sale now!</b></a>,
#  <a href="/beer/profile/710/36010/"><span style="font-size:1.2em; font-weight:bold;">Leinenkugel's Summer Shandy</span></a>,
#  <a href="/beer/profile/710/">Jacob Leinenkugel Brewing Company</a>,
#  <a href="/beer/profile/22656/276455/"><span style="font-size:1.2em; font-weight:bold;">Leinenkugels Summer Shandy</span></a>,
#  <a href="/beer/profile/22656/">Chardon BrewWorks</a>,
#  <a class="OverlayTrigger OverlayCloser" href="lost-password/" tabindex="106">Forgot your password?</a>,
#  <a href="/sponsorship/">Become a BeerAdvocate sponsor</a>,
#  <a class="OverlayTrigger jumpMenuTrigger" data-cacheoverlay="true" href="misc/quick-navigation-menu" title="Open quick navigation"><i class="uix_icon uix_icon-sitemap"></i></a>,
#  <a class="crumb" href="/"><span><i class="uix_icon uix_icon-home" title="Home"></i><span class="uix_breadcrumb__home__title">Home</span></span></a>,
#  <a class="crumb" href="/search/"><span>Search</span></a>,
#  <a class="homeLink" href="https://www.beeradvocate.com">Home</a>,
#  <a "="" href="https://www.beeradvocate.com/contact/">Contact</a>,
#  <a href="threads/frequently-asked-questions-faq.444392/">Help</a>,
#  <a href="https://www.beeradvocate.com/community/threads/terms-of-service.101118/">Terms of Service</a>,
#  <a href="https://www.beeradvocate.com/community/threads/privacy-policy.393415/">Privacy Policy</a>,
#  <a href="/search/?q=Leinenkugel%27s+Summer+Shandy&amp;qt=beer#XenForo"><i class="uix_icon uix_icon-jumpToTop"></i> <span class="uix_hide">Top</span></a>,
#  <a href="/about/">About</a>,
#  <a href="/members/">Community</a>,
#  <a href="/events/">Events</a>,
#  <a href="/sponsorship/">Sponsorship</a>,
#  <a href="/forms/add-beer/">Add a Beer</a>,
#  <a href="/toolbox/add_place/">Add a Place</a>,
#  <a href="/forms/events/">Add an Event</a>,
#  <a href="/community/threads/how-to-claim-your-place.553982/">Claim Your Place</a>,
#  <a href="/events/">Attend a Beer Fest</a>,
#  <a href="/society/">Join the Respect Beer Society</a>,
#  <a href="https://store.beeradvocate.com" target="_blank">Shop</a>,
#  <a href="https://twitter.com/beeradvocate" target="_blank">Twitter</a>,
#  <a href="https://www.instagram.com/beeradvocate/" target="_blank">Instagram</a>,
#  <a href="https://www.facebook.com/beeradvocate/" target="_blank">Facebook</a>,
#  <a href="/contact/">Contact</a>,
#  <a href="https://www.beeradvocate.com/community/threads/frequently-asked-questions-faq.444392/">Help</a>,
#  <a href="http://ba.click/seektadbe1" target="_blank"><img alt="Independent Craft Brewer Seal" border="0" src="https://cdn.beeradvocate.com/im/brewers-association-independent-craft-brewer-seal-supporter.png" style="width: 85px; float: right; margin: 0px 0px 25px 25px;" title="#seektheseal and support #independentbeer"/></a>,
#  <a href="http://ba.click/seektadbe1" target="_blank" title="#seektheseal and support #independentbeer">#seektheseal</a>,
#  <a data-position="top" href="#content" title="Top"><i class="uix_icon uix_icon-jumpToTop"></i></a>,
#  <a data-position="bottom" href="#content" title="Bottom"><i class="uix_icon uix_icon-jumpToBottom"></i></a>,
#  <a class="OverlayTrigger jumpMenuTrigger" data-cacheoverlay="true" href="misc/quick-navigation-menu" title="Open quick navigation"><i class="uix_icon uix_icon-sitemap"></i></a>,
#  <a class="crumb" href="/"><span><i class="uix_icon uix_icon-home" title="Home"></i><span class="uix_breadcrumb__home__title">Home</span></span></a>,
#  <a class="crumb" href="/search/"><span>Search</span></a>]

# %%
for i in soup.find_all('a'):
        if ('beer/profile' in str(i)) and ('span' not in str(i)):
            #print(i)
            print(i.get_text())
            break
# Out:
# Jacob Leinenkugel Brewing Company

# %%
url='https://www.beeradvocate.com/search/?q=Batch+19&qt=beer'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="Public NoJs uix_javascriptNeedsInit LoggedOut Sidebar Responsive pageIsLtr not_hasTabLinks hasSearch is-sidebarOpen hasRightSidebar is-setWidth navStyle_0 pageStyle_0 hasFlexbox" dir="LTR" id="XenForo" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <base href="https://www.beeradvocate.com/community/"/>\n  <script>\n   var _b = document.getElementsByTagName(\'base\')[0], _bH = "https://www.beeradvocate.com/community/";\n\t\t\tif (_b && _b.href != _bH) _b.href = _bH;\n  </script>\n  <title>\n   Search | BeerAdvocate\n  </title>\n  <noscript>\n   <style>\n    .JsOnly, .jsOnly { display: none !important; }\n   </style>\n  </noscript>\n  <link href="css.php?css=xenforo,form,public&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <link href="css.php?css=login_bar,moderator_bar,notices,uix_extendedFooter&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <link href="css.php?css=uix,uix_style&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <style>\n   /*** UIX -- PER USER STYLES ***/\n  </style>\n  <link href="css.php?css=EXTRA&amp;style=6&amp;dir=LTR&amp;d=1560810676" rel="stylesheet"/>\n  <style>\n   /* Node Styling */\n  </style>\n  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1066712-1">\n  </script>\n  <script>\n   window.dataLayer = window.dataLayer || [];\n\t\tfunction gtag(){dataLayer.push(arguments);}\n\t\tgtag(\'js\', new Date());\n\t\tgtag(\'config\', \'UA-1066712-1\', {\n  \t\t\t\'cookie_domain\': \'www.beeradvocate.com\',\n\t\t\t// <!-- slot: ga_config_start -->\n\t\t\t\n\t\t\t\n\t\t});\n  </script>\n  <link href="styles/uix/uix/css/font-awesome.min.css" rel="stylesheet"/>\n  <link href="//fonts.googleapis.com/css?family=Open+Sans:300,400,700,600" rel="stylesheet" type="text/css"/>\n  <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.7.2/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" rel="stylesheet"/>\n  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">\n  </script>\n  <script>\n   if (!window.jQuery) { document.write(\'<scr\'+\'ipt type="text/javascript" src="js/jquery/jquery-1.11.0.min.js"><\\/scr\'+\'ipt>\'); }\n  </script>\n  <script src="js/xenforo/xenforo.js?_v=3fb40d2d">\n  </script>\n  <!--[if lt IE 9]>\n\t\n\t\t \n        \t<script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.2/html5shiv.min.js"></script>\n\t        \n\t        <script src="//cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.js"></script>\n\t        \n\t        <script src="//cdnjs.cloudflare.com/ajax/libs/selectivizr/1.0.2/selectivizr-min.js"></script>\n\t\n\n<![endif]-->\n  <script>\n   uix = {\n\t\telm: {},\n\t\tfn:{},\n\t\tinit: function(){\n\t\t\tif (uix.betaMode) {\n\t\t\t\tconsole.group(\'uix.%cinit()\', \'color:#3498DB\');\n\t\t\t}\n\t\t\tfor(var x=0;x<uix.events.init.length;x++){\n\t\t\t\tuix.events.init[x]()\n\t\t  \t}\n\t\t  \tconsole.groupEnd(\'uix.%cinit()\',\'color:#3498DB\')\n\t\t},\n\t  \tevents: {init:[]},\n\t  \ton: function(event, fn){\n\t  \t\tif(event==\'init\'){\n\t  \t\t\tuix.events.init.push(fn)\n\t  \t\t}\n\t  \t},\n\n\t\tbetaMode\t\t\t\t: parseInt(\'0\'),\n\t\tjsPathUsed\t\t\t\t: \'uix_style\',\n\t\tjsGlobal\t\t\t\t: parseInt(\'0\'),\n\n\n\t  \tversion\t\t\t\t\t: \'1.5.22.0\',\n\t  \tjsHeadVersion\t\t\t\t: \'1.5.16.0a\',\n\t  \taddonVersion\t\t\t\t: \'1010270\',\n\t  \tjsCacheBust\t\t\t\t: \'1\',\n\t  \tcontentTemplate\t\t\t\t: \'bridge_page\',\n\n\t\tjavascriptInitHide\t\t\t: parseInt(\'1\'),\n\t\tglobalPadding \t\t\t\t: parseInt(\'16px\'),\n\t\tsidebarWidth\t\t\t\t: parseInt(\'300px\'),\n\t\tmainContainerMargin  \t        \t: \'316px\',\n\t\tmaxResponsiveWideWidth   \t\t: parseInt(\'850px\'),\n\t\tmaxResponsiveMediu ...

# %%
for i in soup.find_all('a'):
        if ('beer/profile' in str(i)) and ('span' not in str(i)):
            #print(i)
            print(i.get_text())
            break
# Out:
# Coors Brewing Company (Molson-Coors)

# %%
def
for i in soup.find_all('a'):
    if ('beer/profile' in str(i)) and ('span' not in str(i)):
        #print(i)
        print(i.get_text())
        break
# Out:
# Jacob Leinenkugel Brewing Company
